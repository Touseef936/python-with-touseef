# %%
#File handling 
#File Mode(r(read),w(write),a(append))
#simply perform that operation
f1=open('file.xlsx',"w")
f1.write("Python Is important")
f1.close()

f1=open('file.xlsx',"r")
print(f1.read())
f1.close

f1=open('file.xlsx',"a")
f1.write("Practice it daily")
f1.close()

f1=open('file.xlsx',"r")
print(f1.read())
f1.close()
# Out:
# Python Is important
# Python Is importantPractice it daily

# %%
# Csv file read/write
import pandas as pd 
data={"name":["Ravi","Rajesh","Rakesh"],"age":[25,26,27]}
df=pd.DataFrame(data)
df.to_csv("people-100.csv")  #write

df=pd.read_csv("people-100.csv") #read
print(df)

#json file read/write
import pandas as pd 
data={"name":["Raza","Ahmed","ALi"],"age":[21,22,23]}
df=pd.DataFrame(data)
df.to_json("people-100.json")  #write

df=pd.read_json("people-100.json")
print(df)
# Out:
#    Unnamed: 0    name  age
# 0           0    Ravi   25
# 1           1  Rajesh   26
# 2           2  Rakesh   27
#     name  age
# 0   Raza   21
# 1  Ahmed   22
# 2    ALi   23

# %%
#regex 
import re 
pattern= "[a-zA-z0-9]@[a-zA-z+./[com|net|edu]]"
user_input=input()
if (re.search(pattern,user_input)):
    print("valid")
else :
    print("invalid")
# Out:
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$5(SequenceExecutionState.scala:132)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:132)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# ...

# %%
import os
import shutil

# Ask the user for the directory path to organize
path = "/Workspace/Users/touseefrafique939@gmail.com"

# List all files in the given directory
files = os.listdir(path)
print(files)  # Optional: to verify files are listed

# Loop through each file in the directory
for file in files:
    # Split the filename and extension
    filename, extension = os.path.splitext(file)
    # Remove the dot from the extension
    extension = extension[1:]
    print(extension)  # Optional: to verify extension extraction

    # Construct the path for the folder named after the extension
    folder_path = os.path.join(path, extension)

    # Check if the folder exists; if not, create it
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Construct full file paths for source and destination
    source = os.path.join(path, file)
    destination = os.path.join(folder_path, file)

    # Move the file to the appropriate folder
    shutil.move(source, destination)

print("Files have been organized successfully.")
# Out:
# ['ipynb', 'xlsx', 'csv', 'json']
#
#
#
#
# Files have been organized successfully.
